# %% [markdown]
# # Qualcomm Cloud AI - MLPerf Inference - Getting Started Guide
#
# ### By [Dr Anton Lokhmotov](https://www.linkedin.com/in/lokhmotov/), Krai Ltd

# %% [markdown]
# # Table of Contents
#
# 1. [Systems](#systems)
#   1. [`r282_z93_q5`](#systems_r282)
#
# 1. [Benchmark](#benchmark) (reproduce v1.0)
#   1. [Offline](#benchmark_offline)
#     1. [Accuracy](#benchmark_offline_accuracy)
#     1. [Performance](#benchmark_offline_performance)
#     1. [Power](#benchmark_offline_power)
#     1. [Compliance](#benchmark_offline_compliance)
#   1. [Server](#benchmark_server)
#     1. [Accuracy](#benchmark_server_accuracy)
#     1. [Performance](#benchmark_server_performance)
#     1. [Power](#benchmark_server_power)
#     1. [Compliance](#benchmark_server_compliance)
#
# 1. [Make quick runs](#quick)
#   1. [Single Stream](#quick_singlestream)
#   1. [Offline](#quick_offline)
#   1. [Server](#quick_server)
#
# 1. [Tune](#tune) **TODO**

# %% [markdown]
# <a name="systems"></a>
# # Systems

# %% [markdown]
# <a name="systems_r282"></a>
# ## `r282_z93_q5` ([Gigabyte R282-Z93](https://www.gigabyte.com/Enterprise/Rack-Server/R282-Z93-rev-115)-Q5)

# %% [markdown]
# ### Check the OS
#
# <pre><b>[anton@dyson ~]&dollar;</b> rpm -q centos-release
# centos-release-7-9.2009.1.el7.centos.x86_64</pre>
#
# <pre><b>[anton@dyson ~]&dollar;</b> uname -a
# Linux dyson.localdomain 5.4.1-1.el7.elrepo.x86_64 #1 SMP Fri Nov 29 10:21:13 EST 2019 x86_64 x86_64 x86_64 GNU/Linux</pre>

# %% [markdown]
# ### Check the CPU
#
# <pre><b>[anton@dyson ~]&dollar;</b> lscpu
# Architecture:          x86_64
# CPU op-mode(s):        32-bit, 64-bit
# Byte Order:            Little Endian
# CPU(s):                64
# On-line CPU(s) list:   0-63
# Thread(s) per core:    2
# Core(s) per socket:    16
# Socket(s):             2
# NUMA node(s):          2
# Vendor ID:             AuthenticAMD
# CPU family:            23
# Model:                 49
# Model name:            AMD EPYC 7282 16-Core Processor
# Stepping:              0
# CPU MHz:               1423.724
# CPU max MHz:           2800.0000
# CPU min MHz:           1500.0000
# BogoMIPS:              5600.18
# Virtualization:        AMD-V
# L1d cache:             32K
# L1i cache:             32K
# L2 cache:              512K
# L3 cache:              16384K
# NUMA node0 CPU(s):     0-15,32-47
# NUMA node1 CPU(s):     16-31,48-63
# Flags:                 fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ht syscall nx mmxext fxsr_opt pdpe1gb rdtscp lm constant_tsc rep_good nopl nonstop_tsc cpuid extd_apicid aperfmperf pni pclmulqdq monitor ssse3 fma cx16 sse4_1 sse4_2 movbe popcnt aes xsave avx f16c rdrand lahf_lm cmp_legacy svm extapic cr8_legacy abm sse4a misalignsse 3dnowprefetch osvw ibs skinit wdt tce topoext perfctr_core perfctr_nb bpext perfctr_llc mwaitx cpb cat_l3 cdp_l3 hw_pstate sme ssbd mba sev ibrs ibpb stibp vmmcall fsgsbase bmi1 avx2 smep bmi2 cqm rdt_a rdseed adx smap clflushopt clwb sha_ni xsaveopt xsavec xgetbv1 xsaves cqm_llc cqm_occup_llc cqm_mbm_total cqm_mbm_local clzero irperf xsaveerptr wbnoinvd arat npt lbrv svm_lock nrip_save tsc_scale vmcb_clean flushbyasid decodeassists pausefilter pfthreshold avic v_vmsave_vmload vgif umip rdpid overflow_recov succor smca
# </pre>

# %% [markdown]
# ### Check the Platform and Apps SDKs
#
# <pre>
# <b>[anton@dyson ~]&dollar;</b> cat /opt/qti-aic/versions/platform.xml</pre>
# ```
# <versions>
#         <ci_build>
#            <base_name>AIC</base_name>
#            <base_version>1.5</base_version>
#            <build_id>9</build_id>
#         </ci_build>
#         </versions>
# ```
#
# <pre>
# <b>[anton@dyson ~]&dollar;</b> cat /opt/qti-aic/versions/apps.xml</pre>
# ```
# <versions>
#             <ci_build>
#                 <base_name>AIC</base_name>
#                 <base_version>1.5</base_version>
#                 <build_id>9</build_id>
#             </ci_build>
#          </versions>
# ```

# %% [markdown]
# ### Check for the presence of five 16-NSP cards
#
# <pre>
# <b>[anton@dyson ~]&dollar;</b> groups
# krai root docker qaic
# <b>[anton@dyson ~]&dollar;</b> /opt/qti-aic/tools/qaic-util -q
# LRT QC_IMAGE_VERSION: LRT.AIC.5.2.1.5.6
# LRT IMAGE_VARIANT: LRT.AIC.REL
# Number of devices: 5
# QID 0
#         Status:Ready
#         PCI Address:0000:01:00.0
#         PCI Info:Processing accelerators Qualcomm Device a100
#         HW Version:0.2.0.0
#         HW Serial:0xa2008f8a
#         FW Version:1.5.6
#         FW QC_IMAGE_VERSION:QSM.AIC.1.5.6
#         FW OEM_IMAGE_VERSION:
#         FW IMAGE_VARIANT:AIC100.REL
#         NSP Version:1.5.2
#         NSP QC_IMAGE_VERSION:NSP.AIC.1.5.2
#         NSP OEM_IMAGE_VERSION:
#         NSP IMAGE_VARIANT:aic100.nsp.prodQ
#         Compiler Version:0
#         Dram Total:16308 MB
#         Dram Free:16308 MB
#         Dram Fragmentation:0.00%
#         Vc Total:16
#         Vc Free:16
#         Nsp Total:16
#         Nsp Free:16
#         Peak Dram Bw:0.0
#         Peak Sram Bw:0.0
#         Peak PcieBw:0.0
#         MCID Total:3072
#         MCID Free:3072
#         Semaphore Total:32
#         Semaphore Free:32
#         Constants Loaded:0
#         Constants In-Use:0
#         Networks Loaded:0
#         Networks Active:0
#         NSP Frequency(Mhz):825
#         DDR Frequency(Mhz):2133
#         COMPNOC Frequency(Mhz):1450
#         MEMNOC Frequency(Mhz):1000
#         SYSNOC Frequency(Mhz):667
#         Metadata Version:0.10
#         NNC Command Protocol Version:8.0
#         SBL Image:SBL.AIC.1.5.5
#         PVS Image Version:18
#         NSP Defective PG Mask: 0x0
#         Board serial:PN471-1-24300C2
# QID 1
#         Status:Ready
#         PCI Address:0000:81:00.0
#         PCI Info:Processing accelerators Qualcomm Device a100
#         HW Version:0.2.0.0
#         HW Serial:0x3e656b13
#         FW Version:1.5.6
#         FW QC_IMAGE_VERSION:QSM.AIC.1.5.6
#         FW OEM_IMAGE_VERSION:
#         FW IMAGE_VARIANT:AIC100.REL
#         NSP Version:1.5.2
#         NSP QC_IMAGE_VERSION:NSP.AIC.1.5.2
#         NSP OEM_IMAGE_VERSION:
#         NSP IMAGE_VARIANT:aic100.nsp.prodQ
#         Compiler Version:0
#         Dram Total:16308 MB
#         Dram Free:16308 MB
#         Dram Fragmentation:0.00%
#         Vc Total:16
#         Vc Free:16
#         Nsp Total:16
#         Nsp Free:16
#         Peak Dram Bw:0.0
#         Peak Sram Bw:0.0
#         Peak PcieBw:0.0
#         MCID Total:3072
#         MCID Free:3072
#         Semaphore Total:32
#         Semaphore Free:32
#         Constants Loaded:0
#         Constants In-Use:0
#         Networks Loaded:0
#         Networks Active:0
#         NSP Frequency(Mhz):825
#         DDR Frequency(Mhz):2133
#         COMPNOC Frequency(Mhz):1450
#         MEMNOC Frequency(Mhz):1000
#         SYSNOC Frequency(Mhz):667
#         Metadata Version:0.10
#         NNC Command Protocol Version:8.0
#         SBL Image:SBL.AIC.1.5.5
#         PVS Image Version:18
#         NSP Defective PG Mask: 0x0
#         Board serial:PN471-1-24300C2
# QID 2
#         Status:Ready
#         PCI Address:0000:a1:00.0
#         PCI Info:Processing accelerators Qualcomm Device a100
#         HW Version:0.2.0.0
#         HW Serial:0xf0a5655d
#         FW Version:1.5.6
#         FW QC_IMAGE_VERSION:QSM.AIC.1.5.6
#         FW OEM_IMAGE_VERSION:
#         FW IMAGE_VARIANT:AIC100.REL
#         NSP Version:1.5.2
#         NSP QC_IMAGE_VERSION:NSP.AIC.1.5.2
#         NSP OEM_IMAGE_VERSION:
#         NSP IMAGE_VARIANT:aic100.nsp.prodQ
#         Compiler Version:0
#         Dram Total:16308 MB
#         Dram Free:16308 MB
#         Dram Fragmentation:0.00%
#         Vc Total:16
#         Vc Free:16
#         Nsp Total:16
#         Nsp Free:16
#         Peak Dram Bw:0.0
#         Peak Sram Bw:0.0
#         Peak PcieBw:0.0
#         MCID Total:3072
#         MCID Free:3072
#         Semaphore Total:32
#         Semaphore Free:32
#         Constants Loaded:0
#         Constants In-Use:0
#         Networks Loaded:0
#         Networks Active:0
#         NSP Frequency(Mhz):825
#         DDR Frequency(Mhz):2133
#         COMPNOC Frequency(Mhz):1450
#         MEMNOC Frequency(Mhz):1000
#         SYSNOC Frequency(Mhz):667
#         Metadata Version:0.10
#         NNC Command Protocol Version:8.0
#         SBL Image:SBL.AIC.1.5.5
#         PVS Image Version:18
#         NSP Defective PG Mask: 0x0
#         Board serial:PN471-1-24300C2
# QID 3
#         Status:Ready
#         PCI Address:0000:a2:00.0
#         PCI Info:Processing accelerators Qualcomm Device a100
#         HW Version:0.2.0.0
#         HW Serial:0xe0560598
#         FW Version:1.5.6
#         FW QC_IMAGE_VERSION:QSM.AIC.1.5.6
#         FW OEM_IMAGE_VERSION:
#         FW IMAGE_VARIANT:AIC100.REL
#         NSP Version:1.5.2
#         NSP QC_IMAGE_VERSION:NSP.AIC.1.5.2
#         NSP OEM_IMAGE_VERSION:
#         NSP IMAGE_VARIANT:aic100.nsp.prodQ
#         Compiler Version:0
#         Dram Total:16308 MB
#         Dram Free:16308 MB
#         Dram Fragmentation:0.00%
#         Vc Total:16
#         Vc Free:16
#         Nsp Total:16
#         Nsp Free:16
#         Peak Dram Bw:0.0
#         Peak Sram Bw:0.0
#         Peak PcieBw:0.0
#         MCID Total:3072
#         MCID Free:3072
#         Semaphore Total:32
#         Semaphore Free:32
#         Constants Loaded:0
#         Constants In-Use:0
#         Networks Loaded:0
#         Networks Active:0
#         NSP Frequency(Mhz):825
#         DDR Frequency(Mhz):2133
#         COMPNOC Frequency(Mhz):1450
#         MEMNOC Frequency(Mhz):1000
#         SYSNOC Frequency(Mhz):667
#         Metadata Version:0.10
#         NNC Command Protocol Version:8.0
#         SBL Image:SBL.AIC.1.5.5
#         PVS Image Version:18
#         NSP Defective PG Mask: 0x0
#         Board serial:PN471-1-24300C2
# QID 4
#         Status:Ready
#         PCI Address:0000:c1:00.0
#         PCI Info:Processing accelerators Qualcomm Device a100
#         HW Version:0.2.0.0
#         HW Serial:0x76fada51
#         FW Version:1.5.6
#         FW QC_IMAGE_VERSION:QSM.AIC.1.5.6
#         FW OEM_IMAGE_VERSION:
#         FW IMAGE_VARIANT:AIC100.REL
#         NSP Version:1.5.2
#         NSP QC_IMAGE_VERSION:NSP.AIC.1.5.2
#         NSP OEM_IMAGE_VERSION:
#         NSP IMAGE_VARIANT:aic100.nsp.prodQ
#         Compiler Version:0
#         Dram Total:16308 MB
#         Dram Free:16308 MB
#         Dram Fragmentation:0.00%
#         Vc Total:16
#         Vc Free:16
#         Nsp Total:16
#         Nsp Free:16
#         Peak Dram Bw:0.0
#         Peak Sram Bw:0.0
#         Peak PcieBw:0.0
#         MCID Total:3072
#         MCID Free:3072
#         Semaphore Total:32
#         Semaphore Free:32
#         Constants Loaded:0
#         Constants In-Use:0
#         Networks Loaded:0
#         Networks Active:0
#         NSP Frequency(Mhz):825
#         DDR Frequency(Mhz):2133
#         COMPNOC Frequency(Mhz):1450
#         MEMNOC Frequency(Mhz):1000
#         SYSNOC Frequency(Mhz):667
#         Metadata Version:0.10
#         NNC Command Protocol Version:8.0
#         SBL Image:SBL.AIC.1.5.5
#         PVS Image Version:18
#         NSP Defective PG Mask: 0x0
#         Board serial:PN471-1-24300C2
# </pre>

# %% [markdown]
# ### Monitor the system (snapshots taken under the full load)
#
# #### Sensors
#
# <pre><b>[anton@dyson ~]&dollar;</b> watch -n 10 "sensors | grep qaic-pci -A7"
# Every 10.0s: sensors | grep qaic-pci -A7
#
# qaic-pci-c100
# Adapter: PCI adapter
# temp1:        +63.0°C  (highest = +63.0°C)
# temp2:        +94.0°C  (crit = +88.0°C, emerg = +93.0°C)
#  (highest = +96.0°C)
# temp3:            N/A
# power1:       68.00 W  (max =  66.00 W)
#
# qaic-pci-a200
# Adapter: PCI adapter
# temp1:        +64.0°C  (highest = +64.0°C)
# temp2:        +88.0°C  (crit = +88.0°C, emerg = +93.0°C)
#  (highest = +91.0°C)
# temp3:            N/A
# power1:       66.00 W  (max =  66.00 W)
#
# --
# qaic-pci-8100
# Adapter: PCI adapter
# temp1:        +65.0°C  (highest = +65.0°C)
# temp2:        +95.0°C  (crit = +88.0°C, emerg = +93.0°C)
#  (highest = +96.0°C)
# temp3:            N/A
# power1:       59.00 W  (max =  66.00 W)
#
# qaic-pci-a100
# Adapter: PCI adapter
# temp1:        +66.0°C  (highest = +66.0°C)
# temp2:        +92.0°C  (crit = +88.0°C, emerg = +93.0°C)
#  (highest = +95.0°C)
# temp3:            N/A
# power1:       63.00 W  (max =  66.00 W)
#
# qaic-pci-0100
# Adapter: PCI adapter
# temp1:        +73.0°C  (highest = +73.0°C)
# temp2:        +88.0°C  (crit = +88.0°C, emerg = +93.0°C)
#  (highest = +96.0°C)
# temp3:            N/A
# power1:       63.00 W  (max =  66.00 W)
# </pre>
#
# #### Frequencies
#
# <pre><b>[anton@dyson ~]&dollar;</b> watch -n 10 "/opt/qti-aic/tools/qaic-util -q | grep NSP\ Freq"
# Every 10.0s: /opt/qti-aic/tools/qaic-util -q | grep NSP\ Freq
#
#         NSP Frequency(Mhz):1450
#         NSP Frequency(Mhz):1209
#         NSP Frequency(Mhz):1333
#         NSP Frequency(Mhz):1267
#         NSP Frequency(Mhz):1209
# </pre>

# %% [markdown]
# <a name="set_fans"></a>
# ## Set the fan speed at 6,750 RPM
#
# <pre>
# <b>[anton@dyson ~]&dollar;</b> ipmitool -I lanplus -U admin -P password -H 172.24.66.70 raw 0x2e 0x10 0x0a 0x3c 0 64 1 <b>75</b> 0xFF
# <b>[anton@dyson ~]&dollar;</b> ipmitool -I lanplus -U admin -P password -H 172.24.66.70 sensor get BPB_FAN_1A
# Locating sensor record...
# Sensor ID              : BPB_FAN_1A (0xa0)
#  Entity ID             : 29.1
#  Sensor Type (Threshold)  : Fan
#  Sensor Reading        : <b>6750 (+/- 0) RPM</b>
#  Status                : ok
#  Lower Non-Recoverable : na
#  Lower Critical        : 1200.000
#  Lower Non-Critical    : 1500.000
#  Upper Non-Critical    : na
#  Upper Critical        : na
#  Upper Non-Recoverable : na
#  Positive Hysteresis   : Unspecified
#  Negative Hysteresis   : 150.000
#  Assertion Events      :
#  Assertions Enabled    : lnc- lcr-
#  Deassertions Enabled  : lnc- lcr-
# </pre>
#
# **NB:** The system when idle consumes ~160 W at 6,750 RPM and ~140 W at 3,000 RPM.

# %% [markdown]
# <a name="set_platform_scripts"></a>
# ## Set platform scripts (ECC on)
#
# <pre>
# <b>[anton@dyson ~]&dollar;</b> ck detect platform.os --platform_init_uoa=qaic
#
# OS CK UOA:            linux-64 (4258b5fe54828a50)
#
# OS name:              CentOS Linux 7 (Core)
# Short OS name:        Linux 5.4.1
# Long OS name:         Linux-5.4.1-1.el7.elrepo.x86_64-x86_64-with-centos-7.9.2009-Core
# OS bits:              64
# OS ABI:               x86_64
#
# Platform init UOA:    qaic
#
# <b>[anton@dyson ~]&dollar;</b> cat $(ck find repo:local)/cfg/local-platform/.cm/meta.json
# {
#   "platform_init_uoa": {
#     "linux-64": "qaic"
#   }
# }
# </pre>

# %% [markdown]
# <a name="benchmark"></a>
# # Benchmark

# %% [markdown]
# <a name="benchmark_offline"></a>
# ## <font color="#2AA197">Offline</font>

# %% [markdown]
# <a name="benchmark_offline_accuracy"></a>
# ### <font color="#268BD2">Accuracy</font>

# %% [markdown]
# #### [Submitted experiment](https://github.com/mlcommons/inference_results_v1.0/blob/master/closed/Qualcomm/results/r282_z93_q5-qaic-v1.3.14-aic100/resnet50/offline/accuracy/accuracy.txt)
#
# <pre>
# accuracy=75.928%, good=37964, total=50000
# hash=10373eeb2c4574ed28dccbd553cb4a3399c35dc99d6c3b6d1530413a9108feff
# </pre>

# %% [markdown]
# #### Reproduced experiment
#
# <pre>
# <b>[anton@dyson ~]&dollar;</b> time ck run cmdgen:benchmark.image-classification.qaic-loadgen --verbose \
# <font color="#d226ff"><b>--sut=r282_z93_q5</b></font> <font color="#daa520"><b>--library=qaic-v1.3.14-aic100</b></font> <font color="#B58900"><b>--model=resnet50</b></font> <font color="#2AA197"><b>--scenario=offline</b></font> \
# <font color="#268BD2"><b>--mode=accuracy</b></font> <font color="#d2268b"><b>--dataset_size=50000</b></font> <font color="#6d26d2"><b>--buffer_size=5000</b></font>
# ...
# accuracy=75.928%, good=37964, total=50000
# ==========================================================================================
#
# real    1m6.660s
# user    3m58.657s
# sys     1m50.909s
#
# <b>[anton@dyson ~]&dollar;</b> ck list experiment:*<font color="#B58900"><b>resnet50</b></font>*<font color="#2AA197"><b>offline</b></font>*<font color="#268BD2"><b>accuracy</b></font>*
# mlperf-closed-<font color="#d226ff"><b>r282_z93_q5</b></font>-<font color="#daa520"><b>qaic-v1.3.14-aic100</b></font>-<font color="#B58900"><b>resnet50.pcie.16nsp-resnet50</b></font>-<font color="#2AA197"><b>offline</b></font>-<font color="#268BD2"><b>accuracy</b></font>-<font color="#d2268b"><b>dataset_size.50000</b></font>-preprocessed_using.opencv-<font color="#6d26d2"><b>buffer_size.5000</b></font>
# </pre>

# %% [markdown]
# <a name="benchmark_offline_performance"></a>
# ### <font color="#268BD2">Performance</font>

# %% [markdown]
# #### [Submitted experiment](https://github.com/mlcommons/inference_results_v1.0/blob/master/closed/Qualcomm/results/r282_z93_q5-qaic-v1.3.14-aic100/resnet50/offline/performance/run_1/mlperf_log_summary.txt) (power/testing)
#
# <pre>
# ...
# ================================================
# MLPerf Results Summary
# ================================================
# SUT name : QAIC_SUT
# <font color="#2AA197"><b>Scenario : Offline</b></font>
# Mode     : PerformanceOnly
# Samples per second: 100077
# Result is : VALID
#   Min duration satisfied : Yes
#   Min queries satisfied : Yes
#
# ================================================
# Additional Stats
# ================================================
# Min latency (ns)                : 2476850
# Max latency (ns)                : 659491153403
# Mean latency (ns)               : 45571906351
# 50.00 percentile latency (ns)   : 322708757934
# 90.00 percentile latency (ns)   : 591963818083
# 95.00 percentile latency (ns)   : 625711131028
# 97.00 percentile latency (ns)   : 639218831720
# 99.00 percentile latency (ns)   : 652737225042
# 99.90 percentile latency (ns)   : 658818719087
#
# ================================================
# Test Parameters Used
# ================================================
# samples_per_query : 66000000
# <font color="#2AA197"><b>target_qps : 100000</b></font>
# target_latency (ns): 0
# max_async_queries : 1
# min_duration (ms): 600000
# max_duration (ms): 0
# min_query_count : 1
# max_query_count : 0
# qsl_rng_seed : 7322528924094909334
# sample_index_rng_seed : 1570999273408051088
# schedule_rng_seed : 3507442325620259414
# accuracy_log_rng_seed : 0
# accuracy_log_probability : 0
# accuracy_log_sampling_target : 0
# print_timestamps : 0
# performance_issue_unique : 0
# performance_issue_same : 0
# performance_issue_same_index : 0
# <font color="#6d26d2"><b>performance_sample_count : 1024</b></font>
#
# No warnings encountered during test.
#
# No errors encountered during test.
# </pre>

# %% [markdown]
# #### Reproduced experiment #1
#
# <pre>
# <b>[anton@dyson ~]&dollar;</b> time ck run cmdgen:benchmark.image-classification.qaic-loadgen --verbose \
# <font color="#d226ff"><b>--sut=r282_z93_q5</b></font> <font color="#daa520"><b>--library=qaic-v1.3.14-aic100</b></font> <font color="#B58900"><b>--model=resnet50</b></font> <font color="#2AA197"><b>--scenario=offline</b></font> \
# <font color="#268BD2"><b>--mode=performance</b></font> <font color="#2AA197"><b>--target_qps=100000</b></font> <font color="#d2268b"><b>--dataset_size=50000</b></font> <font color="#6d26d2"><b>--buffer_size=1024</b></font>
# ...
# ================================================
# MLPerf Results Summary
# ================================================
# SUT name : QAIC_SUT
# <font color="#2AA197"><b>Scenario : Offline</b></font>
# Mode     : PerformanceOnly
# Samples per second: 101346
# Result is : VALID
#   Min duration satisfied : Yes
#   Min queries satisfied : Yes
#
# ================================================
# Additional Stats
# ================================================
# Min latency (ns)                : 2137501
# Max latency (ns)                : 651233704790
# Mean latency (ns)               : 39902631689
# 50.00 percentile latency (ns)   : 315260321636
# 90.00 percentile latency (ns)   : 583354688114
# 95.00 percentile latency (ns)   : 617282218238
# 97.00 percentile latency (ns)   : 630864702435
# 99.00 percentile latency (ns)   : 644470152221
# 99.90 percentile latency (ns)   : 650557674078
#
# ================================================
# Test Parameters Used
# ================================================
# samples_per_query : 66000000
# <font color="#2AA197"><b>target_qps : 100000</b></font>
# target_latency (ns): 0
# max_async_queries : 1
# min_duration (ms): 600000
# max_duration (ms): 0
# min_query_count : 1
# max_query_count : 0
# qsl_rng_seed : 7322528924094909334
# sample_index_rng_seed : 1570999273408051088
# schedule_rng_seed : 3507442325620259414
# accuracy_log_rng_seed : 0
# accuracy_log_probability : 0
# accuracy_log_sampling_target : 0
# print_timestamps : 0
# performance_issue_unique : 0
# performance_issue_same : 0
# performance_issue_same_index : 0
# <font color="#6d26d2"><b>performance_sample_count : 1024</b></font>
#
# No warnings encountered during test.
#
# No errors encountered during test.
# ==========================================================================================
#
# real    11m25.254s
# user    104m43.621s
# sys     8m8.304s
#
# <b>[anton@dyson ~]&dollar;</b> ck list experiment:*<font color="#B58900"><b>resnet50</b></font>*<font color="#2AA197"><b>offline</b></font>*<font color="#268BD2"><b>performance</b></font>*
# mlperf-closed-<font color="#d226ff"><b>r282_z93_q5</b></font>-<font color="#daa520"><b>qaic-v1.3.14-aic100</b></font>-<font color="#B58900"><b>resnet50.pcie.16nsp-resnet50</b></font>-<font color="#2AA197"><b>offline</b></font>-<font color="#268BD2"><b>performance</b></font>-<font color="#2AA197"><b>target_qps.100000</b></font>-<font color="#6d26d2"><b>buffer_size.1024</b></font>
# </pre>

# %% [markdown]
# <a name="benchmark_offline_power"></a>
# ### <font color="#268BD2">Power</font>

# %% [markdown]
# <pre>
# <b>[anton@dyson ~]&dollar;</b> time ck run cmdgen:benchmark.image-classification.qaic-loadgen --verbose \
# <font color="#d226ff"><b>--sut=r282_z93_q5</b></font> <font color="#daa520"><b>--library=qaic-v1.3.14-aic100</b></font> <font color="#B58900"><b>--model=resnet50</b></font> <font color="#2AA197"><b>--scenario=offline</b></font> \
# <font color="#268BD2"><b>--mode=performance</b></font> <font color="#2AA197"><b>--target_qps=100000</b></font> <font color="#d2268b"><b>--dataset_size=50000</b></font> <font color="#6d26d2"><b>--buffer_size=1024</b></font> \
# <font color="#268BD2"><b>--power=yes --power_server_ip=172.24.66.69 --power_server_port=4951 --sleep_before_ck_benchmark_sec=90</b></font>
# ...
# real    27m19.134s
# user    203m16.845s
# sys     15m56.988s
#
# <b>[anton@dyson ~]&dollar;</b> ck list experiment:*<font color="#B58900"><b>resnet50</b></font>*<font color="#2AA197"><b>offline</b></font>*<font color="#268BD2"><b>power</b></font>*
# mlperf-closed-<font color="#d226ff"><b>r282_z93_q5</b></font>-<font color="#daa520"><b>qaic-v1.3.14-aic100</b></font>-<font color="#B58900"><b>resnet50.pcie.16nsp-resnet50</b></font>-<font color="#2AA197"><b>offline</b></font>-<font color="#268BD2"><b>performance</b></font>-<font color="#2AA197"><b>target_qps.100000</b></font>-<font color="#6d26d2"><b>buffer_size.1024</b></font>-<font color="#268BD2"><b>power.workload</b></font>
# mlperf-closed-<font color="#d226ff"><b>r282_z93_q5</b></font>-<font color="#daa520"><b>qaic-v1.3.14-aic100</b></font>-<font color="#B58900"><b>resnet50.pcie.16nsp-resnet50</b></font>-<font color="#2AA197"><b>offline</b></font>-<font color="#268BD2"><b>performance</b></font>-<font color="#2AA197"><b>target_qps.100000</b></font>-<font color="#6d26d2"><b>buffer_size.1024</b></font>-<font color="#268BD2"><b>power.client</b></font>
# </pre>

# %% [markdown]
# <a name="benchmark_offline_compliance"></a>
# ### <font color="#268BD2">Compliance</font>

# %% [markdown]
# #### TEST01, TEST05

# %% [markdown]
# <pre>
# <b>[anton@dyson ~]&dollar;</b> time ck run cmdgen:benchmark.image-classification.qaic-loadgen --verbose \
# <font color="#d226ff"><b>--sut=r282_z93_q5</b></font> <font color="#daa520"><b>--library=qaic-v1.3.14-aic100</b></font> <font color="#B58900"><b>--model=resnet50</b></font> <font color="#2AA197"><b>--scenario=offline</b></font> \
# <font color="#268BD2"><b>--compliance,=TEST05,TEST01</b></font> <font color="#2AA197"><b>--target_qps=100000</b></font> <font color="#d2268b"><b>--dataset_size=50000</b></font> <font color="#6d26d2"><b>--buffer_size=1024</b></font>
# ...
# real    23m23.204s
# user    182m26.617s
# sys     14m59.955s
#
# <b>[anton@dyson ~]&dollar;</b> ck list experiment:*<font color="#B58900"><b>resnet50</b></font>*<font color="#2AA197"><b>offline</b></font>*<font color="#268BD2"><b>compliance</b></font>*
# mlperf-closed-<font color="#d226ff"><b>r282_z93_q5</b></font>-<font color="#daa520"><b>qaic-v1.3.14-aic100</b></font>-<font color="#B58900"><b>resnet50.pcie.16nsp-resnet50</b></font>-<font color="#2AA197"><b>offline</b></font>-<font color="#268BD2"><b>performance</b></font>-<font color="#268BD2"><b>compliance.TEST05</b></font>-<font color="#2AA197"><b>target_qps.100000</b></font>-<font color="#6d26d2"><b>buffer_size.1024</b></font>
# mlperf-closed-<font color="#d226ff"><b>r282_z93_q5</b></font>-<font color="#daa520"><b>qaic-v1.3.14-aic100</b></font>-<font color="#B58900"><b>resnet50.pcie.16nsp-resnet50</b></font>-<font color="#2AA197"><b>offline</b></font>-<font color="#268BD2"><b>performance</b></font>-<font color="#268BD2"><b>compliance.TEST01</b></font>-<font color="#2AA197"><b>target_qps.100000</b></font>-<font color="#6d26d2"><b>buffer_size.1024</b></font>
# </pre>

# %% [markdown]
# <a name="benchmark_server"></a>
# ## <font color="#2AA197">Server</font>

# %% [markdown]
# <a name="benchmark_server_accuracy"></a>
# ### <font color="#268BD2">Accuracy</font>

# %% [markdown]
# #### [Submitted experiment](https://github.com/mlcommons/inference_results_v1.0/blob/master/closed/Qualcomm/results/r282_z93_q5-qaic-v1.3.14-aic100/resnet50/server/accuracy/accuracy.txt)
#
# <pre>
# accuracy=75.928%, good=37964, total=50000
# hash=6be8ef2034bcfd22cbd8ff02f00aed7cb9fb72e0205616d93183fc8d203890a8
# </pre>

# %% [markdown]
# #### Reproduced experiment
#
# <pre>
# <b>[anton@dyson ~]&dollar;</b> time ck run cmdgen:benchmark.image-classification.qaic-loadgen --verbose \
# <font color="#d226ff"><b>--sut=r282_z93_q5</b></font> <font color="#daa520"><b>--library=qaic-v1.3.14-aic100</b></font> <font color="#B58900"><b>--model=resnet50</b></font> <font color="#2AA197"><b>--scenario=server</b></font> \
# <font color="#268BD2"><b>--mode=accuracy</b></font> <font color="#2AA197"><b>--target_qps=78525</b></font> <font color="#d2268b"><b>--dataset_size=50000</b></font> <font color="#6d26d2"><b>--buffer_size=5000</b></font>
# ...
# accuracy=75.928%, good=37964, total=50000
# ==========================================================================================
#
# real    0m32.261s
# user    0m23.143s
# sys     0m8.852s
#
# <b>[anton@dyson ~]&dollar;</b> ck list experiment:*<font color="#B58900"><b>resnet50</b></font>*<font color="#2AA197"><b>server</b></font>*<font color="#268BD2"><b>accuracy</b></font>*
# mlperf-closed-<font color="#d226ff"><b>r282_z93_q5</b></font>-<font color="#daa520"><b>qaic-v1.3.14-aic100</b></font>-<font color="#B58900"><b>resnet50.pcie.16nsp-resnet50</b></font>-<font color="#2AA197"><b>server</b></font>-<font color="#268BD2"><b>accuracy</b></font>-<font color="#d2268b"><b>dataset_size.50000</b></font>-preprocessed_using.opencv-<font color="#2AA197"><b>target_qps.78525</b></font>-<font color="#6d26d2"><b>buffer_size.5000</b></font>
# </pre>

# %% [markdown]
# <a name="benchmark_server_performance"></a>
# ### <font color="#268BD2">Performance</font>

# %% [markdown]
# #### [Submitted experiment](https://github.com/mlcommons/inference_results_v1.0/blob/master/closed/Qualcomm/results/r282_z93_q5-qaic-v1.3.14-aic100/resnet50/server/performance/run_1/mlperf_log_summary.txt)
#
# <pre>
# ...
# ================================================
# MLPerf Results Summary
# ================================================
# SUT name : QAIC_SUT
# <font color="#2AA197"><b>Scenario : Server</b></font>
# Mode     : PerformanceOnly
# Scheduled samples per second : 78501.87
# Result is : VALID
#   Performance constraints satisfied : Yes
#   Min duration satisfied : Yes
#   Min queries satisfied : Yes
#
# ================================================
# Additional Stats
# ================================================
# Completed samples per second    : 78500.33
#
# Min latency (ns)                : 1799886
# Max latency (ns)                : 27716414
# Mean latency (ns)               : 2468824
# 50.00 percentile latency (ns)   : 2284844
# 90.00 percentile latency (ns)   : 2881637
# 95.00 percentile latency (ns)   : 3107617
# 97.00 percentile latency (ns)   : 3264774
# 99.00 percentile latency (ns)   : 3992095
# 99.90 percentile latency (ns)   : 24185052
#
# ================================================
# Test Parameters Used
# ================================================
# samples_per_query : 1
# <font color="#2AA197"><b>target_qps : 78525</b></font>
# target_latency (ns): 15000000
# max_async_queries : 0
# min_duration (ms): 600000
# max_duration (ms): 0
# min_query_count : 270336
# max_query_count : 0
# qsl_rng_seed : 7322528924094909334
# sample_index_rng_seed : 1570999273408051088
# schedule_rng_seed : 3507442325620259414
# accuracy_log_rng_seed : 0
# accuracy_log_probability : 0
# accuracy_log_sampling_target : 0
# print_timestamps : 0
# performance_issue_unique : 0
# performance_issue_same : 0
# performance_issue_same_index : 0
# <font color="#6d26d2"><b>performance_sample_count : 1024</b></font>
#
# 1 warning encountered. See detailed log.
#
# No errors encountered during test.
# </pre>

# %% [markdown]
# #### Reproduced experiment #1
#
# <pre>
# <b>[anton@dyson ~]&dollar;</b> time ck run cmdgen:benchmark.image-classification.qaic-loadgen --verbose \
# <font color="#d226ff"><b>--sut=r282_z93_q5</b></font> <font color="#daa520"><b>--library=qaic-v1.3.14-aic100</b></font> <font color="#B58900"><b>--model=resnet50</b></font> <font color="#2AA197"><b>--scenario=server</b></font> \
# <font color="#268BD2"><b>--mode=performance</b></font> <font color="#2AA197"><b>--target_qps=78525</b></font> <font color="#d2268b"><b>--dataset_size=50000</b></font> <font color="#6d26d2"><b>--buffer_size=1024</b></font>
# ...
# ================================================
# MLPerf Results Summary
# ================================================
# SUT name : QAIC_SUT
# <font color="#2AA197"><b>Scenario : Server</b></font>
# Mode     : PerformanceOnly
# Scheduled samples per second : 78501.87
# Result is : VALID
#   Performance constraints satisfied : Yes
#   Min duration satisfied : Yes
#   Min queries satisfied : Yes
#
# ================================================
# Additional Stats
# ================================================
# Completed samples per second    : 78500.34
#
# Min latency (ns)                : 1803855
# Max latency (ns)                : 24678986
# Mean latency (ns)               : 2572484
# 50.00 percentile latency (ns)   : 2372831
# 90.00 percentile latency (ns)   : 3193833
# 95.00 percentile latency (ns)   : 3508865
# 97.00 percentile latency (ns)   : 3827010
# 99.00 percentile latency (ns)   : 4589709
# 99.90 percentile latency (ns)   : 19156652
#
# ================================================
# Test Parameters Used
# ================================================
# samples_per_query : 1
# <font color="#2AA197"><b>target_qps : 78525</b></font>
# target_latency (ns): 15000000
# max_async_queries : 0
# min_duration (ms): 600000
# max_duration (ms): 0
# min_query_count : 270336
# max_query_count : 0
# qsl_rng_seed : 7322528924094909334
# sample_index_rng_seed : 1570999273408051088
# schedule_rng_seed : 3507442325620259414
# accuracy_log_rng_seed : 0
# accuracy_log_probability : 0
# accuracy_log_sampling_target : 0
# print_timestamps : 0
# performance_issue_unique : 0
# performance_issue_same : 0
# performance_issue_same_index : 0
# <font color="#6d26d2"><b>performance_sample_count : 1024</b></font>
#
# 1 warning encountered. See detailed log.
#
# No errors encountered during test.
# ==========================================================================================
#
# real    11m19.900s
# user    83m27.404s
# sys     6m17.084s
#
# <b>[anton@dyson ~]&dollar;</b> ck list experiment:*<font color="#B58900"><b>resnet50</b></font>*<font color="#2AA197"><b>server</b></font>*<font color="#268BD2"><b>performance</b></font>*
# mlperf-closed-<font color="#d226ff"><b>r282_z93_q5</b></font>-<font color="#daa520"><b>qaic-v1.3.14-aic100</b></font>-<font color="#B58900"><b>resnet50.pcie.16nsp-resnet50</b></font>-<font color="#2AA197"><b>server</b></font>-<font color="#268BD2"><b>performance</b></font>-<font color="#2AA197"><b>target_qps.78525</b></font>-<font color="#2AA197"><b>target_qps.78525</b></font>-<font color="#6d26d2"><b>buffer_size.1024</b></font>
# </pre>

# %% [markdown]
# <a name="benchmark_server_power"></a>
# ### <font color="#268BD2">Power</font>

# %% [markdown]
# <pre>
# <b>[anton@dyson ~]&dollar;</b> time ck run cmdgen:benchmark.image-classification.qaic-loadgen --verbose \
# <font color="#d226ff"><b>--sut=r282_z93_q5</b></font> <font color="#daa520"><b>--library=qaic-v1.3.14-aic100</b></font> <font color="#B58900"><b>--model=resnet50</b></font> <font color="#2AA197"><b>--scenario=server</b></font> \
# <font color="#268BD2"><b>--mode=performance</b></font> <font color="#2AA197"><b>--target_qps=78525</b></font> <font color="#d2268b"><b>--dataset_size=50000</b></font> <font color="#6d26d2"><b>--buffer_size=1024</b></font> \
# <font color="#268BD2"><b>--power=yes --power_server_ip=172.24.66.69 --power_server_port=4951 --sleep_before_ck_benchmark_sec=90</b></font>
# ...
#
# <b>[anton@dyson ~]&dollar;</b> ck list experiment:*<font color="#B58900"><b>resnet50</b></font>*<font color="#2AA197"><b>server</b></font>*<font color="#268BD2"><b>power</b></font>*
# mlperf-closed-<font color="#d226ff"><b>r282_z93_q5</b></font>-<font color="#daa520"><b>qaic-v1.3.14-aic100</b></font>-<font color="#B58900"><b>resnet50.pcie.16nsp-resnet50</b></font>-<font color="#2AA197"><b>server</b></font>-<font color="#268BD2"><b>performance</b></font>-<font color="#2AA197"><b>target_qps.78525</b></font>-<font color="#2AA197"><b>target_qps.78525</b></font>-<font color="#6d26d2"><b>buffer_size.1024</b></font>-<font color="#268BD2"><b>power.workload</b></font>
# mlperf-closed-<font color="#d226ff"><b>r282_z93_q5</b></font>-<font color="#daa520"><b>qaic-v1.3.14-aic100</b></font>-<font color="#B58900"><b>resnet50.pcie.16nsp-resnet50</b></font>-<font color="#2AA197"><b>server</b></font>-<font color="#268BD2"><b>performance</b></font>-<font color="#2AA197"><b>target_qps.78525</b></font>-<font color="#2AA197"><b>target_qps.78525</b></font>-<font color="#6d26d2"><b>buffer_size.1024</b></font>-<font color="#268BD2"><b>power.client</b></font>
# </pre>

# %% [markdown]
# <a name="benchmark_server_compliance"></a>
# ### <font color="#268BD2">Compliance</font>

# %% [markdown]
# #### TEST04-A, TEST04-B, TEST01
#
# <pre>
# <b>[anton@dyson ~]&dollar;</b> time ck run cmdgen:benchmark.image-classification.qaic-loadgen --verbose \
# <font color="#d226ff"><b>--sut=r282_z93_q5</b></font> <font color="#daa520"><b>--library=qaic-v1.3.14-aic100</b></font> <font color="#B58900"><b>--model=resnet50</b></font> <font color="#2AA197"><b>--scenario=server</b></font> \
# <font color="#268BD2"><b>--compliance,=TEST04-A,TEST04-B,TEST01</b></font> <font color="#2AA197"><b>--target_qps=78525</b></font> <font color="#d2268b"><b>--dataset_size=50000</b></font> <font color="#6d26d2"><b>--buffer_size=1024</b></font>
# ...
# real    12m11.494s
# user    80m19.896s
# sys     6m13.616s
#
# <b>[anton@dyson ~]&dollar;</b> ck list experiment:*<font color="#B58900"><b>resnet50</b></font>*<font color="#2AA197"><b>server</b></font>*<font color="#268BD2"><b>compliance</b></font>*
# mlperf-closed-<font color="#d226ff"><b>r282_z93_q5</b></font>-<font color="#daa520"><b>qaic-v1.3.14-aic100</b></font>-<font color="#B58900"><b>resnet50.pcie.16nsp-resnet50</b></font>-<font color="#2AA197"><b>server</b></font>-<font color="#268BD2"><b>performance</b></font>-<font color="#268BD2"><b>compliance.TEST04-A</b></font>-<font color="#2AA197"><b>target_qps.78525</b></font>-<font color="#6d26d2"><b>buffer_size.1024</b></font>
# mlperf-closed-<font color="#d226ff"><b>r282_z93_q5</b></font>-<font color="#daa520"><b>qaic-v1.3.14-aic100</b></font>-<font color="#B58900"><b>resnet50.pcie.16nsp-resnet50</b></font>-<font color="#2AA197"><b>server</b></font>-<font color="#268BD2"><b>performance</b></font>-<font color="#268BD2"><b>compliance.TEST04-B</b></font>-<font color="#2AA197"><b>target_qps.78525</b></font>-<font color="#6d26d2"><b>buffer_size.1024</b></font>
# mlperf-closed-<font color="#d226ff"><b>r282_z93_q5</b></font>-<font color="#daa520"><b>qaic-v1.3.14-aic100</b></font>-<font color="#B58900"><b>resnet50.pcie.16nsp-resnet50</b></font>-<font color="#2AA197"><b>server</b></font>-<font color="#268BD2"><b>performance</b></font>-<font color="#268BD2"><b>compliance.TEST01</b></font>-<font color="#2AA197"><b>target_qps.78525</b></font>-<font color="#6d26d2"><b>buffer_size.1024</b></font>
# <a name="benchmark_server_compliance"></a></pre>

# %% [markdown]
# <a name="quick"></a>
# # Make quick runs
#
# From v1.0, performance runs must take at least 10 minutes, according to the [rules](https://github.com/mlcommons/inference_policies/blob/master/inference_rules.adoc#3-scenarios). We present some LoadGen quirks to reduce the run duration for quick testing.

# %% [markdown]
# <a name="quick_singlestream"></a>
# ## <font color="#2AA197">SingleStream</font>

# %% [markdown]
# <a name="quick_singlestream_valid"></a>
# ### <font color="#2AA197">Valid</font> (&ge; 10 minutes; &ge; 1024 queries, 1 sample per query)
#
# To make a valid [Single Stream performance](https://github.com/krai/ck-qaic/blob/main/program/image-classification-qaic-loadgen/README.singlestream.md#performance) run, specify the expected target latency in milliseconds. LoadGen
# should then generate a sufficient number of queries to satisfy the required minimum duration of 10 minutes.

# %% [markdown]
# <pre>
# <b>[anton@dyson ~]&dollar;</b> time ck run cmdgen:benchmark.image-classification.qaic-loadgen --verbose \
# <font color="#d226ff"><b>--sut=r282_z93_q5</b></font> <font color="#daa520"><b>--sdk=1.5.9</b></font> <font color="#B58900"><b>--model=resnet50</b></font> <font color="#268BD2"><b>--mode=performance</b></font> \
# <font color="#2AA197"><b>--scenario=singlestream</b></font> <font color="#2AA197"><b>--target_latency=1.6</b></font>
# ...
# ================================================
# MLPerf Results Summary
# ================================================
# SUT name : QAIC_SUT
# Scenario : SingleStream
# Mode     : PerformanceOnly
# 90th percentile latency (ns) : 1563940
# Result is : VALID
#   Min duration satisfied : Yes
#   Min queries satisfied : Yes
#
# ================================================
# Additional Stats
# ================================================
# QPS w/ loadgen overhead         : 647.15
# QPS w/o loadgen overhead        : 652.12
#
# Min latency (ns)                : 1441041
# Max latency (ns)                : 15074226
# Mean latency (ns)               : 1533468
# 50.00 percentile latency (ns)   : 1530730
# 90.00 percentile latency (ns)   : 1563940
# 95.00 percentile latency (ns)   : 1572971
# 97.00 percentile latency (ns)   : 1578131
# 99.00 percentile latency (ns)   : 1586491
# 99.90 percentile latency (ns)   : 1603200
#
# ================================================
# Test Parameters Used
# ================================================
# samples_per_query : 1
# target_qps : 1000
# target_latency (ns): 0
# max_async_queries : 1
# min_duration (ms): 600000
# max_duration (ms): 0
# min_query_count : 1024
# max_query_count : 0
# qsl_rng_seed : 1624344308455410291
# sample_index_rng_seed : 517984244576520566
# schedule_rng_seed : 10051496985653635065
# accuracy_log_rng_seed : 0
# accuracy_log_probability : 0
# accuracy_log_sampling_target : 0
# print_timestamps : 0
# performance_issue_unique : 0
# performance_issue_same : 0
# performance_issue_same_index : 0
# performance_sample_count : 1024
#
# No warnings encountered during test.
#
# No errors encountered during test.
# ==========================================================================================
#
# real    10m39.362s
# user    14m5.215s
# sys     38m55.426s
# </pre>

# %% [markdown]
# <a name="quick_singlestream_quick"></a>
# ### <font color="#d2268b">Quick</font> (&lt; 10 minutes)

# %% [markdown]
# <a name="quick_singlestream_quick_duration"></a>
# #### <font color="#d2268b">Reduce the duration</font> (&lt; 10 minutes; &ge; 1,024 queries)
#
# You can "lie" to LoadGen about the expected target latency to reduce the run duration. In the below example, we simply multiply the expected latency by 10.

# %% [markdown]
# <pre>
# <b>[anton@dyson ~]&dollar;</b> time ck run cmdgen:benchmark.image-classification.qaic-loadgen --verbose \
# <font color="#d226ff"><b>--sut=r282_z93_q5</b></font> <font color="#daa520"><b>--sdk=1.5.9</b></font> <font color="#B58900"><b>--model=resnet50</b></font> <font color="#268BD2"><b>--mode=performance</b></font>
# <font color="#2AA197"><b>--scenario=singlestream</b></font> <font color="#d2268b"><b>--target_latency=16</b></font>
# ...
# ================================================
# MLPerf Results Summary
# ================================================
# SUT name : QAIC_SUT
# Scenario : SingleStream
# Mode     : PerformanceOnly
# 90th percentile latency (ns) : 1562361
# <font color="#ff268b"><b>Result is : INVALID</b></font>
# <font color="#ff268b"><b>  Min duration satisfied : NO</b></font>
#   Min queries satisfied : Yes
# Recommendations:
#  * Decrease the expected latency so the loadgen pre-generates more queries.
#
# ================================================
# Additional Stats
# ================================================
# QPS w/ loadgen overhead         : 647.13
# QPS w/o loadgen overhead        : 651.97
#
# Min latency (ns)                : 1448930
# Max latency (ns)                : 13572075
# Mean latency (ns)               : 1533810
# 50.00 percentile latency (ns)   : 1530471
# 90.00 percentile latency (ns)   : 1562361
# 95.00 percentile latency (ns)   : 1572561
# 97.00 percentile latency (ns)   : 1578611
# 99.00 percentile latency (ns)   : 1587751
# 99.90 percentile latency (ns)   : 1605671
#
# ================================================
# Additional Stats
# ================================================
# QPS w/ loadgen overhead         : 647.13
# QPS w/o loadgen overhead        : 651.97
#
# Min latency (ns)                : 1448930
# Max latency (ns)                : 13572075
# Mean latency (ns)               : 1533810
# 50.00 percentile latency (ns)   : 1530471
# 90.00 percentile latency (ns)   : 1562361
# 95.00 percentile latency (ns)   : 1572561
# 97.00 percentile latency (ns)   : 1578611
# 99.00 percentile latency (ns)   : 1587751
# 99.90 percentile latency (ns)   : 1605671
#
# ================================================
# Test Parameters Used
# ================================================
# samples_per_query : 1
# <font color="#d2268b"><b>target_qps : 62.5</b></font>
# target_latency (ns): 0
# max_async_queries : 1
# min_duration (ms): 600000
# max_duration (ms): 0
# min_query_count : 1024
# max_query_count : 0
# qsl_rng_seed : 1624344308455410291
# sample_index_rng_seed : 517984244576520566
# schedule_rng_seed : 10051496985653635065
# accuracy_log_rng_seed : 0
# accuracy_log_probability : 0
# accuracy_log_sampling_target : 0
# print_timestamps : 0
# performance_issue_unique : 0
# performance_issue_same : 0
# performance_issue_same_index : 0
# performance_sample_count : 1024
#
# No warnings encountered during test.
#
# 1 ERROR encountered. See detailed log.
# ==========================================================================================
#
# real    2m30.808s
# user    2m56.666s
# sys     7m34.060s
# </pre>

# %% [markdown]
# <a name="quick_singlestream_quick_count"></a>
# #### <font color="#d2268b">Reduce the query count</font> (&lt; 10 minutes, &lt; 1024 queries)
#
# Alternatively, you can specify the exact number of queries. Note that the target latency will then be ignored (it gets reset to 1000).

# %% [markdown]
# <pre>
# <b>[anton@dyson ~]&dollar;</b> time ck run cmdgen:benchmark.image-classification.qaic-loadgen --verbose \
# <font color="#d226ff"><b>--sut=r282_z93_q5</b></font> <font color="#daa520"><b>--sdk=1.5.9</b></font> <font color="#B58900"><b>--model=resnet50</b></font> <font color="#2AA197"><b>--scenario=singlestream</b></font> \
# <font color="#268BD2"><b>--mode=performance</b></font> <font color="#2AA197"><b>--target_latency=1.6</b></font> <font color="#d2268b"><b>--query_count=500</b></font>
# ...
# ================================================
# MLPerf Results Summary
# ================================================
# SUT name : QAIC_SUT
# Scenario : SingleStream
# Mode     : PerformanceOnly
# 90th percentile latency (ns) : 1582731
# <font color="#ff268b"><b>Result is : INVALID</b></font>
# <font color="#ff268b"><b>  Min duration satisfied : NO</b></font>
#   Min queries satisfied : Yes
# Recommendations:
#  * Decrease the expected latency so the loadgen pre-generates more queries.
#
# ================================================
# Additional Stats
# ================================================
# QPS w/ loadgen overhead         : 632.93
# QPS w/o loadgen overhead        : 635.82
#
# Min latency (ns)                : 1494931
# Max latency (ns)                : 13462275
# Mean latency (ns)               : 1572783
# 50.00 percentile latency (ns)   : 1543510
# 90.00 percentile latency (ns)   : 1582731
# 95.00 percentile latency (ns)   : 1594001
# 97.00 percentile latency (ns)   : 1600571
# 99.00 percentile latency (ns)   : 1799330
# 99.90 percentile latency (ns)   : 13462275
#
# ================================================
# Additional Stats
# ================================================
# QPS w/ loadgen overhead         : 632.93
# QPS w/o loadgen overhead        : 635.82
#
# Min latency (ns)                : 1494931
# Max latency (ns)                : 13462275
# Mean latency (ns)               : 1572783
# 50.00 percentile latency (ns)   : 1543510
# 90.00 percentile latency (ns)   : 1582731
# 95.00 percentile latency (ns)   : 1594001
# 97.00 percentile latency (ns)   : 1600571
# 99.00 percentile latency (ns)   : 1799330
# 99.90 percentile latency (ns)   : 13462275
#
# ================================================
# Test Parameters Used
# ================================================
# samples_per_query : 1
# <font color="#d2268b"><b>target_qps : 1000</b></font>
# target_latency (ns): 0
# max_async_queries : 1
# min_duration (ms): 600000
# max_duration (ms): 0
# <font color="#d2268b"><b>min_query_count : 500</b></font>
# <font color="#d2268b"><b>max_query_count : 500</b></font>
# qsl_rng_seed : 1624344308455410291
# sample_index_rng_seed : 517984244576520566
# schedule_rng_seed : 10051496985653635065
# accuracy_log_rng_seed : 0
# accuracy_log_probability : 0
# accuracy_log_sampling_target : 0
# print_timestamps : 0
# performance_issue_unique : 0
# performance_issue_same : 0
# performance_issue_same_index : 0
# performance_sample_count : 1024
#
# No warnings encountered during test.
#
# 1 ERROR encountered. See detailed log.
# ==========================================================================================
#
# real    0m29.014s
# user    0m14.610s
# sys     0m8.117s
# </pre>

# %% [markdown]
# <a name="quick_offline"></a>
# ## <font color="#2AA197">Offline</font>

# %% [markdown]
# <a name="quick_offline_valid"></a>
# ### <font color="#2AA197">Valid</font> (&ge; 10 minutes; &ge; 24,576 samples in 1 query)
#
# To make a valid [Offline performance](https://github.com/krai/ck-qaic/blob/main/program/image-classification-qaic-loadgen/README.offline.md#performance) run, specify the expected target throughput in samples per second. LoadGen
# should then process a sufficient number of samples to satisfy the required minimum duration of 10 minutes.

# %% [markdown]
# <pre>
# <b>[anton@dyson ~]&dollar;</b> time ck run cmdgen:benchmark.image-classification.qaic-loadgen --verbose \
# <font color="#d226ff"><b>--sut=r282_z93_q5</b></font> <font color="#daa520"><b>--sdk=1.5.9</b></font> <font color="#B58900"><b>--model=resnet50</b></font> <font color="#268BD2"><b>--mode=performance</b></font> \
# <font color="#2AA197"><b>--scenario=offline</b></font> <font color="#2AA197"><b>--target_qps=105000</b></font>
# ...
# ================================================
# MLPerf Results Summary
# ================================================
# SUT name : QAIC_SUT
# Scenario : Offline
# Mode     : PerformanceOnly
# Samples per second: 102769
# Result is : VALID
#   Min duration satisfied : Yes
#   Min queries satisfied : Yes
#
# ================================================
# Additional Stats
# ================================================
# Min latency (ns)                : 2468311
# Max latency (ns)                : 674327002618
# Mean latency (ns)               : 70646318007
# 50.00 percentile latency (ns)   : 336730766694
# 90.00 percentile latency (ns)   : 606580124520
# 95.00 percentile latency (ns)   : 640422579633
# 97.00 percentile latency (ns)   : 653993412956
# 99.00 percentile latency (ns)   : 667544902813
# 99.90 percentile latency (ns)   : 673649074506
#
# ================================================
# Test Parameters Used
# ================================================
# samples_per_query : 69300000
# <font color="#2AA197"><b>target_qps : 105000</b></font>
# target_latency (ns): 0
# max_async_queries : 1
# min_duration (ms): 600000
# max_duration (ms): 0
# min_query_count : 1
# max_query_count : 0
# qsl_rng_seed : 1624344308455410291
# sample_index_rng_seed : 517984244576520566
# schedule_rng_seed : 10051496985653635065
# accuracy_log_rng_seed : 0
# accuracy_log_probability : 0
# accuracy_log_sampling_target : 0
# print_timestamps : 0
# performance_issue_unique : 0
# performance_issue_same : 0
# performance_issue_same_index : 0
# performance_sample_count : 1024
#
# No warnings encountered during test.
#
# No errors encountered during test.
# ==========================================================================================
#
# real    12m35.595s
# user    51m1.858s
# sys     42m28.912s
# </pre>

# %% [markdown]
# <a name="quick_offline_quick"></a>
# ### <font color="#d2268b">Quick</font> (&lt; 10 minutes)

# %% [markdown]
# <a name="quick_singlestream_quick_duration"></a>
# #### <font color="#d2268b">Reduce the duration</font> (&lt; 10 minutes)
#
# You can "lie" to LoadGen about the expected target throughput to reduce the run duration. In the below example, we simply divide the expected throughput by 10.

# %% [markdown]
# <pre>
# <b>[anton@dyson ~]&dollar;</b> time ck run cmdgen:benchmark.image-classification.qaic-loadgen --verbose \
# <font color="#d226ff"><b>--sut=r282_z93_q5</b></font> <font color="#daa520"><b>--sdk=1.5.9</b></font> <font color="#B58900"><b>--model=resnet50</b></font> <font color="#268BD2"><b>--mode=performance</b></font> \
# <font color="#2AA197"><b>--scenario=offline</b></font> <font color="#d2268b"><b>--target_qps=10500</b></font>
# ...
# ================================================
# MLPerf Results Summary
# ================================================
# SUT name : QAIC_SUT
# Scenario : Offline
# Mode     : PerformanceOnly
# Samples per second: 103121
# <font color="#ff268b"><b>Result is : INVALID</b></font>
# <font color="#ff268b"><b>Min duration satisfied : NO</b></font>
#   Min queries satisfied : Yes
# Recommendations:
# <font color="#ff268b"><b> * Increase expected QPS so the loadgen pre-generates a larger (coalesced) query.</b></font>
#
# ================================================
# Additional Stats
# ================================================
# Min latency (ns)                : 2226001
# Max latency (ns)                : 67202580864
# Mean latency (ns)               : 33589545452
# 50.00 percentile latency (ns)   : 33579722609
# 90.00 percentile latency (ns)   : 60472732627
# 95.00 percentile latency (ns)   : 63834510139
# 97.00 percentile latency (ns)   : 65182155721
# 99.00 percentile latency (ns)   : 66528717783
# 99.90 percentile latency (ns)   : 67136964510
#
# ================================================
# Test Parameters Used
# ================================================
# samples_per_query : 6930000
# <font color="#d2268b"><b>target_qps : 10500</b></font>
# target_latency (ns): 0
# max_async_queries : 1
# min_duration (ms): 600000
# max_duration (ms): 0
# min_query_count : 1
# max_query_count : 0
# qsl_rng_seed : 1624344308455410291
# sample_index_rng_seed : 517984244576520566
# schedule_rng_seed : 10051496985653635065
# accuracy_log_rng_seed : 0
# accuracy_log_probability : 0
# accuracy_log_sampling_target : 0
# print_timestamps : 0
# performance_issue_unique : 0
# performance_issue_same : 0
# performance_issue_same_index : 0
# performance_sample_count : 1024
#
# No warnings encountered during test.
# No errors encountered during test.
# ==========================================================================================
#
# real    1m43.264s
# user    5m22.285s
# sys     4m11.255s
# </pre>

# %% [markdown]
# <a name="quick_Server"></a>
# ## <font color="#2AA197">Server</font>

# %% [markdown]
# <a name="quick_server_valid"></a>
# ### <font color="#2AA197">Valid</font> (&ge; 10 minutes; &ge; 270,336 queries, 1 sample per query)
#
# To make a valid [Server performance](https://github.com/krai/ck-qaic/blob/main/program/image-classification-qaic-loadgen/README.server.md#performance) run, specify the expected target throughput in queries per second. LoadGen
# should then process a sufficient number of queries to satisfy the required minimum duration of 10 minutes.

# %% [markdown]
# <pre>
# <b>[anton@dyson ~]&dollar;</b> time ck run cmdgen:benchmark.image-classification.qaic-loadgen --verbose \
# <font color="#d226ff"><b>--sut=r282_z93_q5</b></font> <font color="#daa520"><b>--sdk=1.5.9</b></font> <font color="#B58900"><b>--model=resnet50</b></font> <font color="#268BD2"><b>--mode=performance</b></font> \
# <font color="#2AA197"><b>--scenario=server</b></font> <font color="#2AA197"><b>--target_qps=78500</b></font>
# ...
# ================================================
# MLPerf Results Summary
# ================================================
# SUT name : QAIC_SUT
# Scenario : Server
# Mode     : PerformanceOnly
# Scheduled samples per second : 78511.39
# Result is : VALID
#   Performance constraints satisfied : Yes
#   Min duration satisfied : Yes
#   Min queries satisfied : Yes
#
# ================================================
# Additional Stats
# ================================================
# Completed samples per second    : 78509.85
#
# Min latency (ns)                : 1531623
# Max latency (ns)                : 15079468
# Mean latency (ns)               : 1769069
# 50.00 percentile latency (ns)   : 1746323
# 90.00 percentile latency (ns)   : 1817826
# 95.00 percentile latency (ns)   : 1839675
# 97.00 percentile latency (ns)   : 1854965
# 99.00 percentile latency (ns)   : 1889792
# 99.90 percentile latency (ns)   : 11057740
#
# ================================================
# Test Parameters Used
# ================================================
# samples_per_query : 1
# target_qps : 78500
# target_latency (ns): 15000000
# max_async_queries : 0
# min_duration (ms): 600000
# max_duration (ms): 0
# min_query_count : 270336
# max_query_count : 0
# qsl_rng_seed : 1624344308455410291
# sample_index_rng_seed : 517984244576520566
# schedule_rng_seed : 10051496985653635065
# accuracy_log_rng_seed : 0
# accuracy_log_probability : 0
# accuracy_log_sampling_target : 0
# print_timestamps : 0
# performance_issue_unique : 0
# performance_issue_same : 0
# performance_issue_same_index : 0
# performance_sample_count : 1024
#
# 1 warning encountered. See detailed log.
#
# No errors encountered during test.
# ==========================================================================================
#
# real    11m25.188s
# user    38m44.650s
# sys     43m14.099s
# </pre>

# %% [markdown]
# <a name="quick_offline_quick"></a>
# ### <font color="#d2268b">Quick</font> (&lt; 10 minutes)

# %% [markdown]
# <a name="quick_singlestream_quick_duration"></a>
# #### <font color="#d2268b">Reduce the query count</font> (&lt; 270,336)
#
# You **cannot** "lie" to LoadGen about the expected target throughput to reduce the run duration because this will also decrease the load. You should specify the exact query count. (Internally, this sets the minimum and the maximum query counts to the same value.)

# %% [markdown]
# ##### <font color="#d2268b">--query_count=12345</font>
#
# <pre>
# <b>[anton@dyson ~]&dollar;</b> time ck run cmdgen:benchmark.image-classification.qaic-loadgen --verbose \
# <font color="#d226ff"><b>--sut=r282_z93_q5</b></font> <font color="#daa520"><b>--sdk=1.5.9</b></font> <font color="#B58900"><b>--model=resnet50</b></font> <font color="#268BD2"><b>--mode=performance</b></font> \
# <font color="#2AA197"><b>--scenario=server</b></font> <font color="#2AA197"><b><b>--target_qps=78500</b></font> <font color="#d2268b"><b>--query_count=12345</b></font>
# ...
# ================================================
# MLPerf Results Summary
# ================================================
# SUT name : QAIC_SUT
# Scenario : Server
# Mode     : PerformanceOnly
# Scheduled samples per second : 78285.93
# <font color="#ff268b"><b>Result is : INVALID</b></font>
#   Performance constraints satisfied : Yes
# <font color="#ff268b"><b>  Min duration satisfied : NO</b></font>
#   Min queries satisfied : Yes
# Recommendations:
#  * Increase the target QPS so the loadgen pre-generates more queries.
#
# ================================================
# Additional Stats
# ================================================
# Completed samples per second    : 77443.30
#
# Min latency (ns)                : 1590110
# Max latency (ns)                : 2769252
# Mean latency (ns)               : 1783525
# 50.00 percentile latency (ns)   : 1766767
# 90.00 percentile latency (ns)   : 1856760
# 95.00 percentile latency (ns)   : 1906704
# 97.00 percentile latency (ns)   : 2026858
# 99.00 percentile latency (ns)   : 2419449
# 99.90 percentile latency (ns)   : 2696275
#
# ================================================
# Additional Stats
# ================================================
# Completed samples per second    : 77443.30
#
# Min latency (ns)                : 1590110
# Max latency (ns)                : 2769252
# Mean latency (ns)               : 1783525
# 50.00 percentile latency (ns)   : 1766767
# 90.00 percentile latency (ns)   : 1856760
# 95.00 percentile latency (ns)   : 1906704
# 97.00 percentile latency (ns)   : 2026858
# 99.00 percentile latency (ns)   : 2419449
# 99.90 percentile latency (ns)   : 2696275
#
# ================================================
# Test Parameters Used
# ================================================
# samples_per_query : 1
# target_qps : 78500
# target_latency (ns): 15000000
# max_async_queries : 0
# min_duration (ms): 600000
# max_duration (ms): 0
# <font color="#d2268b"><b>min_query_count : 12345</b></font>
# <font color="#d2268b"><b>max_query_count : 12345</b></font>
# qsl_rng_seed : 1624344308455410291
# sample_index_rng_seed : 517984244576520566
# schedule_rng_seed : 10051496985653635065
# accuracy_log_rng_seed : 0
# accuracy_log_probability : 0
# accuracy_log_sampling_target : 0
# print_timestamps : 0
# performance_issue_unique : 0
# performance_issue_same : 0
# performance_issue_same_index : 0
# performance_sample_count : 1024
#
# 1 warning encountered. See detailed log.
#
# 1 ERROR encountered. See detailed log.
# ==========================================================================================
#
# real    1m16.470s
# user    2m53.342s
# sys     1m57.397s
# </pre>

# %% [markdown]
# ##### <font color="#d2268b"><b>--query_count=123456</b></font>
#
# <pre>
# <b>[anton@dyson ~]&dollar;</b> time ck run cmdgen:benchmark.image-classification.qaic-loadgen --verbose \
# <font color="#d226ff"><b>--sut=r282_z93_q5</b></font> <font color="#daa520"><b>--sdk=1.5.9</b></font> <font color="#B58900"><b>--model=resnet50</b></font> <font color="#268BD2"><b>--mode=performance</b></font> \
# <font color="#2AA197"><b>--scenario=server</b></font> <font color="#2AA197"><b><b>--target_qps=78500</b></font> <font color="#d2268b"><b>--query_count=123456</b></font>
# ...
# ================================================
# MLPerf Results Summary
# ================================================
# SUT name : QAIC_SUT
# Scenario : Server
# Mode     : PerformanceOnly
# Scheduled samples per second : 78344.07
# <font color="#ff268b"><b>Result is : INVALID</b></font>
#   Performance constraints satisfied : Yes
# <font color="#ff268b"><b>  Min duration satisfied : NO</b></font>
#   Min queries satisfied : Yes
# Recommendations:
#  * Increase the target QPS so the loadgen pre-generates more queries.
#
# ================================================
# Additional Stats
# ================================================
# Completed samples per second    : 77768.22
#
# Min latency (ns)                : 1560692
# Max latency (ns)                : 11689978
# Mean latency (ns)               : 1761394
# 50.00 percentile latency (ns)   : 1757739
# 90.00 percentile latency (ns)   : 1831205
# 95.00 percentile latency (ns)   : 1853749
# 97.00 percentile latency (ns)   : 1869806
# 99.00 percentile latency (ns)   : 1907780
# 99.90 percentile latency (ns)   : 2294205
#
# ================================================
# Test Parameters Used
# ================================================
# samples_per_query : 1
# target_qps : 78500
# target_latency (ns): 15000000
# max_async_queries : 0
# min_duration (ms): 600000
# max_duration (ms): 0
# <font color="#d2268b"><b>min_query_count : 123456</b></font>
# <font color="#d2268b"><b>max_query_count : 123456</b></font>
# qsl_rng_seed : 1624344308455410291
# sample_index_rng_seed : 517984244576520566
# schedule_rng_seed : 10051496985653635065
# accuracy_log_rng_seed : 0
# accuracy_log_probability : 0
# accuracy_log_sampling_target : 0
# print_timestamps : 0
# performance_issue_unique : 0
# performance_issue_same : 0
# performance_issue_same_index : 0
# performance_sample_count : 1024
#
# 1 warning encountered. See detailed log.
#
# 1 ERROR encountered. See detailed log.
# ==========================================================================================
#
# real    1m13.980s
# user    2m55.312s
# sys     2m6.865s
# </pre>

# %% [markdown]
# <a name="tune"></a>
# # Tune
